# %% [markdown]
# <a href="https://colab.research.google.com/github/Aashnajaiaswal0510/Data_Science_NF/blob/main/Module1(Python)/Lists_Tuples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Write a program to find the largest and smallest elements in a list
numbers = [12, 45, 7, 89, 23]

largest = max(numbers)
smallest = min(numbers)

print("Largest element:", largest)
print("Smallest element:", smallest)
# Out:
# Largest element: 89
# Smallest element: 7

# %%
#Write a program to remove duplicate elements from a list
numbers = [1, 2, 2, 3, 4, 4, 5]

unique_list = []

for i in numbers:
    if i not in unique_list:
        unique_list.append(i)

print("List after removing duplicates:", unique_list)
# Out:
# List after removing duplicates: [1, 2, 3, 4, 5]

# %%
#Write a program to reverse a list without using built-in reverse functions
numbers = [1, 2, 3, 4, 5]

reversed_list = []

for i in range(len(numbers)-1, -1, -1):
    reversed_list.append(numbers[i])

print("Reversed list:", reversed_list)
# Out:
# Reversed list: [5, 4, 3, 2, 1]

# %%
#Write a program to count even and odd numbers in a list
numbers = [10, 15, 22, 33, 40, 55]

even = 0
odd = 0

for i in numbers:
    if i % 2 == 0:
        even += 1
    else:
        odd += 1

print("Even numbers count:", even)
print("Odd numbers count:", odd)
# Out:
# Even numbers count: 3
# Odd numbers count: 3

# %%
#Write a program to merge two lists and sort the final list
list1 = [5, 2, 8]
list2 = [1, 9, 3]

merged_list = list1 + list2
merged_list.sort()

print("Sorted merged list:", merged_list)
# Out:
# Sorted merged list: [1, 2, 3, 5, 8, 9]

# %%
#Write a program to find the second largest element in a list
numbers = [10, 45, 67, 89, 23]

numbers.sort()

print("Second largest element:", numbers[-2])
# Out:
# Second largest element: 67

# %%
#Write a program to check whether an element exists in a tuple
numbers = (10, 20, 30, 40, 50)

element = int(input("Enter element to search: "))

if element in numbers:
    print("Element exists in tuple")
else:
    print("Element does not exist")
# Out:
# Enter element to search: 5
# Element does not exist

# %%
#Write a program to count the occurrence of an element in a tuple
numbers = (1, 2, 3, 2, 4, 2, 5)

element = int(input("Enter element to count: "))

count = numbers.count(element)

print("Occurrence of element:", count)
# Out:
# Enter element to count: 2
# Occurrence of element: 3

# %%
#Write a program to sort a list of tuples based on tuple values
data = [(2, 5), (1, 2), (4, 1), (3, 7)]

sorted_data = sorted(data, key=lambda x: x[1])

print("Sorted list of tuples:", sorted_data)
# Out:
# Sorted list of tuples: [(4, 1), (1, 2), (2, 5), (3, 7)]

# %%
#Write a program to convert a tuple into a list and a list into a tuple
# Tuple to List
my_tuple = (1, 2, 3, 4)

my_list = list(my_tuple)

print("Converted List:", my_list)

# List to Tuple
numbers = [5, 6, 7, 8]

converted_tuple = tuple(numbers)

print("Converted Tuple:", converted_tuple)
# Out:
# Converted List: [1, 2, 3, 4]
# Converted Tuple: (5, 6, 7, 8)
